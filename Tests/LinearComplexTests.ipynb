# %%
import numpy as np
from scipy import optimize
import scipy
from sklearn import base, metrics
from sklearn.utils.validation import check_X_y
from classifiers import *
from data_generation import *

# %% [markdown]
# ## Compare Performance of AT vs Logistic Regression for Different Label Spaces

# %% [markdown]
# ## Sample Data Generation

# %%
d = 2
k = 4
n = 10000
portions = np.array([2, 4, 7, 8])
X,y = generate_linear_complex_data(d, k, n, portions)

# %%
# Visualize Data
from matplotlib import pyplot as plt
plt.scatter([X[:, 0]], [X[:, 1]], c=[y])

# %% [markdown]
# ## Tests

# %%
def mode(array):
    most = max(list(map(array.count, array)))
    return list(set(filter(lambda x: array.count(x) == most, array)))

# %%
d = 2
k = 15
n = 10000
portions = np.array([2, 4, 7, 8, 10, 14, 17, 19, 23, 26, 28, 30, 33, 35, 38])
X_train,y_train = generate_linear_complex_data(d, k, n, portions)
X_test,y_test = generate_linear_complex_data(d, k, n, portions)
y_train = y_train.astype(int)

# %%
ATs = []
AT_predictions = []
s = 10 # Number of quantiles
for i in range(1, s):
    a = i/s

    clf6 = LogisticQuantileAT(gamma=a, alpha=1.)
    clf6.fit(X_train, y_train)
    ATpredictions = clf6.predict(X_test)
    print('Mean Absolute Error of LogisticQuantileAT, gamma=' + str(a) + ' %s' %
          metrics.mean_absolute_error(ATpredictions, y_test))
    print('0-1 Loss of LogisticQuantileAT, gamma=' + str(a) + ' %s' %
          metrics.zero_one_loss(ATpredictions, y_test))
    ATs.append(clf6)
    AT_predictions.append(ATpredictions)
    
AT_preds = np.zeros((n, 10))
for i in range(1, 10):
    AT_preds[:, i] = AT_predictions[i - 1]
AT_preds = AT_preds.astype(int)
quantile_predictions = np.zeros((n, 1))

for i in range(1, n):
    quantiles = AT_preds[i, :]
    quantile_predictions[i, :] = np.random.choice(mode(quantiles.tolist()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2268a188b787> in <module>()
#       5     a = i/s
#       6
# ----> 7     clf6 = LogisticQuantileAT(gamma=a, alpha=1., kernel_type='linear', kernel_param=1, loss_function='logistic')
#       8     clf6.fit(X_train, y_train)
#       9     ATpredictions = clf6.predict(X_test)
#
# NameError: name 'LogisticQuantileAT' is not defined

# %%
metrics.zero_one_loss(quantile_predictions, y_test)
# Out:
# 0.379

# %%
## Logistic Regression for comparison
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial').fit(X_train, y_train)
metrics.zero_one_loss(clf.predict(X_test), y_test)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.4637

# %%
d = 2
n = 10000

quantile_losses = []
logistic_losses = []
for k in [4, 8, 16, 32, 64]:
    portions = np.cumsum(np.array([3]*k))
    
    X_train,y_train = generate_linear_complex_data(d, k, n, portions)
    X_test,y_test = generate_linear_complex_data(d, k, n, portions)
    y_train = y_train.astype(int)
    
    ATs = []
    AT_predictions = []
    s = int(3 * np.log2(k)) # Number of quantiles
    for i in range(1, s):
        a = i/s

        clf6 = LogisticQuantileAT(gamma=a, alpha=1.)
        clf6.fit(X_train, y_train)
        ATpredictions = clf6.predict(X_test)
        print('Mean Absolute Error of LogisticQuantileAT, gamma=' + str(a) + ' %s' %
              metrics.mean_absolute_error(ATpredictions, y_test))
        print('0-1 Loss of LogisticQuantileAT, gamma=' + str(a) + ' %s' %
              metrics.zero_one_loss(ATpredictions, y_test))
        ATs.append(clf6)
        AT_predictions.append(ATpredictions)

    AT_preds = np.zeros((n, s-1))
    for i in range(1, s):
        AT_preds[:, i-1] = AT_predictions[i - 1]
        AT_preds = AT_preds.astype(int)
        quantile_predictions = np.zeros((n, 1))

    for i in range(1, n):
        quantiles = AT_preds[i, :]
        quantile_predictions[i, :] = np.random.choice(mode(quantiles.tolist()))
        
    q_loss = metrics.zero_one_loss(quantile_predictions, y_test)
    print('LOSS OF QUANTILE CLASSIFIER', q_loss)
    quantile_losses.append(q_loss)
    
    clf = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial').fit(X_train, y_train)
    log_loss = metrics.zero_one_loss(clf.predict(X_test), y_test)
    
    print('LOSS OF LOGISTIV CLASSIFIER', log_loss)
    logistic_losses.append(log_loss)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Absolute Error of LogisticQuantileAT, gamma=0.16666666666666666 0.3904
# 0-1 Loss of LogisticQuantileAT, gamma=0.16666666666666666 0.3517
# Mean Absolute Error of LogisticQuantileAT, gamma=0.3333333333333333 0.2579
# 0-1 Loss of LogisticQuantileAT, gamma=0.3333333333333333 0.22350000000000003
# Mean Absolute Error of LogisticQuantileAT, gamma=0.5 0.235
# 0-1 Loss of LogisticQuantileAT, gamma=0.5 0.20130000000000003
# Mean Absolute Error of LogisticQuantileAT, gamma=0.6666666666666666 0.3295
# 0-1 Loss of LogisticQuantileAT, gamma=0.6666666666666666 0.29379999999999995
# Mean Absolute Error of LogisticQuantileAT, gamma=0.8333333333333334 0.6284
# 0-1 Loss of LogisticQuantileAT, gamma=0.8333333333333334 0.5899
# LOSS OF QUANTILE CLASSIFIER 0.20140000000000002
# LOSS OF LOGISTIV CLASSIFIER 0.19630000000000003
# Mean Absolute Error of LogisticQuantileAT, gamma=0.1111111111111111 0.7622
# 0-1 Loss of LogisticQuantileAT, gamma=0.1111111111111111 0.6665
# Mean Absolute Error of LogisticQuantileAT, gamma=0.2222222222222222 0.5043
# 0-1 Loss of LogisticQuantileAT, gamma=0.2222222222222222 0.4315
# Mean Absolute Error of LogisticQuantileAT, gamma=0.3333333333333333 0.369
# 0-1 Loss of LogisticQuantileAT, gamma=0.3333333333333333 0.2995
# Mean Absolute Error of LogisticQuantileAT, gamma=0.4444444444444444 0.3101
# 0-1 Loss of LogisticQuantileAT, gamma=0.4444444444444444 0.24260000000000004
# Mean Absolute Error of LogisticQuantileAT, gamma=0.5555555555555556 0.3306
# 0-1 Loss of LogisticQuantileAT, gamma=0.5555555555555556 0.26259999999999994
# Mean Absolute Error of LogisticQuantileAT, gamma=0.6666666666666666 0.4438
# 0-1 Loss of LogisticQuantileAT, gamma=0.6666666666666666 0.3718
# Mean Absolute Error of LogisticQuantileAT, gamma=0.7777777777777778 0.6596
# 0-1 Loss of LogisticQuantileAT, gamma=0.7777777777777778 0.5807
# Mean Absolute Error of LogisticQuantileAT, gamma=0.8888888888888888 1.0688
# 0-1 Loss of LogisticQuantileAT, gamma=0.8888888888888888 0.8616
# LOSS OF QUANTILE CLASSIFIER 0.24039999999999995
# LOSS OF LOGISTIV CLASSIFIER 0.2691
# Mean Absolute Error of LogisticQuantileAT, gamma=0.08333333333333333 1.3631
# 0-1 Loss of LogisticQuantileAT, gamma=0.08333333333333333 0.8759
# Mean Absolute Error of LogisticQuantileAT, gamma=0.16666666666666666 0.9318
# 0-1 Loss of LogisticQuantileAT, gamma=0.16666666666666666 0.7251000000000001
# Mean Absolute Error of LogisticQuantileAT, gamma=0.25 0.7082
# 0-1 Loss of LogisticQuantileAT, gamma=0.25 0.5591999999999999
# Mean Absolute Error of LogisticQuantileAT, gamma=0.3333333333333333 0.5739
# 0-1 Loss of LogisticQuantileAT, gamma=0.3333333333333333 0.44110000000000005
# Mean Absolute Error of LogisticQuantileAT, gamma=0.4166666666666667 0.5055
# 0-1 Loss of LogisticQuantileAT, gamma=0.4166666666666667 0.37860000000000005
# Mean Absolute Error of LogisticQuantileAT, gamma=0.5 0.4839
# 0-1 Loss of LogisticQuantileAT, gamma=0.5 0.35729999999999995
# Mean Absolute Error of LogisticQuantileAT, gamma=0.5833333333333334 0.516
# 0-1 Loss of LogisticQuantileAT, gamma=0.5833333333333334 0.3872
# Mean Absolute Error of LogisticQuantileAT, gamma=0.6666666666666666 0.6218
# 0-1 Loss of LogisticQuantileAT, gamma=0.6666666666666666 0.48740000000000006
# Mean Absolute Error of LogisticQuantileAT, gamma=0.75 0.7994
# 0-1 Loss of LogisticQuantileAT, gamma=0.75 0.636
# Mean Absolute Error of LogisticQuantileAT, gamma=0.8333333333333334 1.0956
# 0-1 Loss of LogisticQuantileAT, gamma=0.8333333333333334 0.821
# Mean Absolute Error of LogisticQuantileAT, gamma=0.9166666666666666 1.6921
# 0-1 Loss of LogisticQuantileAT, gamma=0.9166666666666666 0.9388
# LOSS OF QUANTILE CLASSIFIER 0.36970000000000003
# LOSS OF LOGISTIV CLASSIFIER 0.4588
# Mean Absolute Error of LogisticQuantileAT, gamma=0.06666666666666667 2.1775
# 0-1 Loss of LogisticQuantileAT, gamma=0.06666666666666667 0.9323
# Mean Absolute Error of LogisticQuantileAT, gamma=0.13333333333333333 1.5317
# 0-1 Loss of LogisticQuantileAT, gamma=0.13333333333333333 0.8479
# Mean Absolute Error of LogisticQuantileAT, gamma=0.2 1.2216
# 0-1 Loss of LogisticQuantileAT, gamma=0.2 0.754
# Mean Absolute Error of LogisticQuantileAT, gamma=0.26666666666666666 1.0238
# 0-1 Loss of LogisticQuantileAT, gamma=0.26666666666666666 0.663
# Mean Absolute Error of LogisticQuantileAT, gamma=0.3333333333333333 0.9021
# 0-1 Loss of LogisticQuantileAT, gamma=0.3333333333333333 0.6011
# Mean Absolute Error of LogisticQuantileAT, gamma=0.4 0.836
# 0-1 Loss of LogisticQuantileAT, gamma=0.4 0.5634
# Mean Absolute Error of LogisticQuantileAT, gamma=0.4666666666666667 0.8111
# 0-1 Loss of LogisticQuantileAT, gamma=0.4666666666666667 0.5526
# Mean Absolute Error of LogisticQuantileAT, gamma=0.5333333333333333 0.8221
# 0-1 Loss of LogisticQuantileAT, gamma=0.5333333333333333 0.5608
# Mean Absolute Error of LogisticQuantileAT, gamma=0.6 0.8743
# 0-1 Loss of LogisticQuantileAT, gamma=0.6 0.596
# Mean Absolute Error of LogisticQuantileAT, gamma=0.6666666666666666 0.9672
# 0-1 Loss of LogisticQuantileAT, gamma=0.6666666666666666 0.6465000000000001
# Mean Absolute Error of LogisticQuantileAT, gamma=0.7333333333333333 1.1347
# 0-1 Loss of LogisticQuantileAT, gamma=0.7333333333333333 0.7257
# Mean Absolute Error of LogisticQuantileAT, gamma=0.8 1.3893
# 0-1 Loss of LogisticQuantileAT, gamma=0.8 0.8184
# Mean Absolute Error of LogisticQuantileAT, gamma=0.8666666666666667 1.8317
# 0-1 Loss of LogisticQuantileAT, gamma=0.8666666666666667 0.9147
# Mean Absolute Error of LogisticQuantileAT, gamma=0.9333333333333333 2.7433
# 0-1 Loss of LogisticQuantileAT, gamma=0.9333333333333333 0.9726
# LOSS OF QUANTILE CLASSIFIER 0.5669
# LOSS OF LOGISTIV CLASSIFIER 0.7686999999999999
# Mean Absolute Error of LogisticQuantileAT, gamma=0.05555555555555555 3.8586
# 0-1 Loss of LogisticQuantileAT, gamma=0.05555555555555555 0.9654
# Mean Absolute Error of LogisticQuantileAT, gamma=0.1111111111111111 2.7101
# 0-1 Loss of LogisticQuantileAT, gamma=0.1111111111111111 0.9171
# Mean Absolute Error of LogisticQuantileAT, gamma=0.16666666666666666 2.1951
# 0-1 Loss of LogisticQuantileAT, gamma=0.16666666666666666 0.8643000000000001
# Mean Absolute Error of LogisticQuantileAT, gamma=0.2222222222222222 1.8742
# 0-1 Loss of LogisticQuantileAT, gamma=0.2222222222222222 0.8253
# Mean Absolute Error of LogisticQuantileAT, gamma=0.2777777777777778 1.6482
# 0-1 Loss of LogisticQuantileAT, gamma=0.2777777777777778 0.7936
# Mean Absolute Error of LogisticQuantileAT, gamma=0.3333333333333333 1.539
# 0-1 Loss of LogisticQuantileAT, gamma=0.3333333333333333 0.7701
# Mean Absolute Error of LogisticQuantileAT, gamma=0.3888888888888889 1.4168
# 0-1 Loss of LogisticQuantileAT, gamma=0.3888888888888889 0.7569
# Mean Absolute Error of LogisticQuantileAT, gamma=0.4444444444444444 1.366
# 0-1 Loss of LogisticQuantileAT, gamma=0.4444444444444444 0.7483
# Mean Absolute Error of LogisticQuantileAT, gamma=0.5 1.3535
# 0-1 Loss of LogisticQuantileAT, gamma=0.5 0.744
# Mean Absolute Error of LogisticQuantileAT, gamma=0.5555555555555556 1.3782
# 0-1 Loss of LogisticQuantileAT, gamma=0.5555555555555556 0.7493000000000001
# Mean Absolute Error of LogisticQuantileAT, gamma=0.6111111111111112 1.4431
# 0-1 Loss of LogisticQuantileAT, gamma=0.6111111111111112 0.7635000000000001
# Mean Absolute Error of LogisticQuantileAT, gamma=0.6666666666666666 1.5482
# 0-1 Loss of LogisticQuantileAT, gamma=0.6666666666666666 0.7819
# Mean Absolute Error of LogisticQuantileAT, gamma=0.7222222222222222 1.6576
# 0-1 Loss of LogisticQuantileAT, gamma=0.7222222222222222 0.8
# Mean Absolute Error of LogisticQuantileAT, gamma=0.7777777777777778 1.8627
# 0-1 Loss of LogisticQuantileAT, gamma=0.7777777777777778 0.8306
# Mean Absolute Error of LogisticQuantileAT, gamma=0.8333333333333334 2.2026
# 0-1 Loss of LogisticQuantileAT, gamma=0.8333333333333334 0.8815
# Mean Absolute Error of LogisticQuantileAT, gamma=0.8888888888888888 2.6832
# 0-1 Loss of LogisticQuantileAT, gamma=0.8888888888888888 0.9225
# Mean Absolute Error of LogisticQuantileAT, gamma=0.9444444444444444 3.827
# 0-1 Loss of LogisticQuantileAT, gamma=0.9444444444444444 0.9738
# LOSS OF QUANTILE CLASSIFIER 0.7589
# LOSS OF LOGISTIV CLASSIFIER 0.9024

# %%
quantile_losses
# Out:
# [0.6336999999999999, 0.7731, 0.9076, 0.9515, 0.9738]

# %%
logistic_losses
# Out:
# [0.5896, 0.7595000000000001, 0.8746, 0.9399, 0.9713]

# %%
quantile_losses
# Out:
# [0.20140000000000002, 0.24039999999999995, 0.36970000000000003, 0.5669, 0.7589]

# %%
logistic_losses
# Out:
# [0.19630000000000003, 0.2691, 0.4588, 0.7686999999999999, 0.9024]

# %%
clf.predict(X_test)
# Out:
# array([54, 32, 54, ..., 54, 10, 15])
